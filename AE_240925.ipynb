# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from pylab import rcParams
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score

DATA_SPLIT_PCT = 0.2
rcParams['figure.figsize'] = 8, 6
LABELS = ["Normal","Break"]

# %% [markdown]
# <font size='5'>Data preprocessing</font>

# %%
df = pd.read_csv("E:/dataset/ae_data.csv")

# %%
sign = lambda x: (1, -1)[x < 0]

def curve_shift(df, shift_by):
    '''
    This function will shift the binary labels in a dataframe.
    The curve shift will be with respect to the 1s. 
    For example, if shift is -2, the following process
    will happen: if row n is labeled as 1, then
    - Make row (n+shift_by):(n+shift_by-1) = 1.
    - Remove row n.
    i.e. the labels will be shifted up to 2 rows up.
    
    Inputs:
    df       A pandas dataframe with a binary labeled column. 
             This labeled column should be named as 'y'.
    shift_by An integer denoting the number of rows to shift.
    
    Output
    df       A dataframe with the binary labels shifted by shift.
    '''

    vector = df['y'].copy()
    for s in range(abs(shift_by)):
        tmp = vector.shift(sign(shift_by))
        tmp = tmp.fillna(0)
        vector += tmp
    labelcol = 'y'
    # Add vector to the df
    df.insert(loc=0, column=labelcol+'tmp', value=vector)
    # Remove the rows with labelcol == 1.
    df = df.drop(df[df[labelcol] == 1].index)
    # Drop labelcol and rename the tmp col as labelcol
    df = df.drop(labelcol, axis=1)
    df = df.rename(columns={labelcol+'tmp': labelcol})
    # Make the labelcol binary
    df.loc[df[labelcol] > 0, labelcol] = 1

    return df

# %%
# Remove time column, and the categorical columns
df = df.drop(['time', 'x28', 'x61'], axis=1)

# %%
# we divide the data into train, valid, and test sets. 

df_train, df_test = train_test_split(df, test_size=DATA_SPLIT_PCT, random_state=123)
df_train, df_valid = train_test_split(df_train, test_size=DATA_SPLIT_PCT, random_state=123)
df_train_0 = df_train.loc[df['y'] == 0]
df_train_1 = df_train.loc[df['y'] == 1]
df_train_0_x = df_train_0.drop(['y'], axis=1)
df_train_1_x = df_train_1.drop(['y'], axis=1)
df_valid_0 = df_valid.loc[df['y'] == 0]
df_valid_1 = df_valid.loc[df['y'] == 1]
df_valid_0_x = df_valid_0.drop(['y'], axis=1)
df_valid_1_x = df_valid_1.drop(['y'], axis=1)
df_test_0 = df_test.loc[df['y'] == 0]
df_test_1 = df_test.loc[df['y'] == 1]
df_test_0_x = df_test_0.drop(['y'], axis=1)
df_test_1_x = df_test_1.drop(['y'], axis=1)

# %% [markdown]
# Standardization

# %%
scaler = StandardScaler().fit(df_train_0_x)
df_train_0_x_rescaled = scaler.transform(df_train_0_x)
df_valid_0_x_rescaled = scaler.transform(df_valid_0_x)
df_valid_x_rescaled = scaler.transform(df_valid.drop(['y'], axis = 1))
df_test_0_x_rescaled = scaler.transform(df_test_0_x)
df_test_x_rescaled = scaler.transform(df_test.drop(['y'], axis = 1))

# %%
nb_epoch = 200
batch_size = 128
input_dim = df_train_0_x_rescaled.shape[1] #num of predictor variables, 
encoding_dim = 32
hidden_dim = int(encoding_dim / 2)
learning_rate = 1e-3

input_layer = Input(shape=(input_dim, ))
encoder = Dense(encoding_dim, activation="relu", activity_regularizer=regularizers.l1(learning_rate))(input_layer)
encoder = Dense(hidden_dim, activation="relu")(encoder)
decoder = Dense(hidden_dim, activation="relu")(encoder)
decoder = Dense(encoding_dim, activation="relu")(decoder)
decoder = Dense(input_dim, activation="linear")(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)
autoencoder.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 59)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 32)                  │           1,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 32)                  │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 59)                  │           1,947 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,211 (20.36 KB)
#  Trainable params: 5,211 (20.36 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Training

# %%
autoencoder.compile(metrics=['accuracy'],
                    loss='mean_squared_error',
                    optimizer='adam')

history = autoencoder.fit(df_train_0_x_rescaled, df_train_0_x_rescaled,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(df_valid_0_x_rescaled, df_valid_0_x_rescaled),
                    verbose=1).history
# Out:
# Epoch 1/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0238 - loss: 2.3080 - val_accuracy: 0.0437 - val_loss: 1.5301
# Epoch 2/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0391 - loss: 1.3293 - val_accuracy: 0.0673 - val_loss: 1.0516
# Epoch 3/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0676 - loss: 0.9134 - val_accuracy: 0.0359 - val_loss: 0.7971
# Epoch 4/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0541 - loss: 0.7143 - val_accuracy: 0.0909 - val_loss: 0.6768
# Epoch 5/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1064 - loss: 0.5996 - val_accuracy: 0.0950 - val_loss: 0.6216
# Epoch 6/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1005 - loss: 0.5625 - val_accuracy: 0.1097 - val_loss: 0.5896
# Epoch 7/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1267 - loss: 0.5277 - val_accuracy: 0.1285 - val_loss: 0.5650
# Epoch 8/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1404 - loss: 0.4929 - val_accuracy: 0.1446 - val_loss: 0.5455
# Epoch 9/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1641 - loss: 0.4875 - val_accuracy: 0.1541 - val_loss: 0.5316
# Epoch 10/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1645 - loss: 0.4667 - val_accuracy: 0.1832 - val_loss: 0.5178
# Epoch 11/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1932 - loss: 0.4546 - val_accuracy: 0.2016 - val_loss: 0.5023
# Epoch 12/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2087 - loss: 0.4403 - val_accuracy: 0.2174 - val_loss: 0.4867
# Epoch 13/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2126 - loss: 0.4294 - val_accuracy: 0.2355 - val_loss: 0.4657
# Epoch 14/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2261 - loss: 0.4079 - val_accuracy: 0.2515 - val_loss: 0.4523
# Epoch 15/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2415 - loss: 0.3981 - val_accuracy: 0.2594 - val_loss: 0.4353
# Epoch 16/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2494 - loss: 0.3813 - val_accuracy: 0.2611 - val_loss: 0.4250
# Epoch 17/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2600 - loss: 0.3655 - val_accuracy: 0.2594 - val_loss: 0.4156
# Epoch 18/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2707 - loss: 0.3653 - val_accuracy: 0.2690 - val_loss: 0.4060
# Epoch 19/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2740 - loss: 0.3530 - val_accuracy: 0.2874 - val_loss: 0.4006
# Epoch 20/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2946 - loss: 0.3522 - val_accuracy: 0.2802 - val_loss: 0.3929
# Epoch 21/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3050 - loss: 0.3351 - val_accuracy: 0.2843 - val_loss: 0.3860
# Epoch 22/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3084 - loss: 0.3371 - val_accuracy: 0.3110 - val_loss: 0.3853
# Epoch 23/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3170 - loss: 0.3260 - val_accuracy: 0.3233 - val_loss: 0.3780
# Epoch 24/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3282 - loss: 0.3276 - val_accuracy: 0.3524 - val_loss: 0.3730
# Epoch 25/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3415 - loss: 0.3258 - val_accuracy: 0.3636 - val_loss: 0.3654
# Epoch 26/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3572 - loss: 0.3166 - val_accuracy: 0.3380 - val_loss: 0.3654
# Epoch 27/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3440 - loss: 0.3155 - val_accuracy: 0.3626 - val_loss: 0.3594
# Epoch 28/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3433 - loss: 0.3032 - val_accuracy: 0.3489 - val_loss: 0.3576
# Epoch 29/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3541 - loss: 0.2985 - val_accuracy: 0.3312 - val_loss: 0.3532
# Epoch 30/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3539 - loss: 0.2947 - val_accuracy: 0.3592 - val_loss: 0.3506
# Epoch 31/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3562 - loss: 0.2924 - val_accuracy: 0.3483 - val_loss: 0.3506
# Epoch 32/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3524 - loss: 0.2951 - val_accuracy: 0.3397 - val_loss: 0.3462
# Epoch 33/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3581 - loss: 0.2897 - val_accuracy: 0.3554 - val_loss: 0.3451
# Epoch 34/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3652 - loss: 0.2909 - val_accuracy: 0.3599 - val_loss: 0.3424
# Epoch 35/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3731 - loss: 0.2849 - val_accuracy: 0.3780 - val_loss: 0.3406
# Epoch 36/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3702 - loss: 0.2836 - val_accuracy: 0.3859 - val_loss: 0.3390
# Epoch 37/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3646 - loss: 0.2830 - val_accuracy: 0.3776 - val_loss: 0.3356
# Epoch 38/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3760 - loss: 0.2798 - val_accuracy: 0.3876 - val_loss: 0.3329
# Epoch 39/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3988 - loss: 0.2815 - val_accuracy: 0.3934 - val_loss: 0.3302
# Epoch 40/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3908 - loss: 0.2778 - val_accuracy: 0.3712 - val_loss: 0.3343
# Epoch 41/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3866 - loss: 0.2754 - val_accuracy: 0.3906 - val_loss: 0.3292
# Epoch 42/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4044 - loss: 0.2726 - val_accuracy: 0.3835 - val_loss: 0.3313
# Epoch 43/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3963 - loss: 0.2693 - val_accuracy: 0.4101 - val_loss: 0.3289
# Epoch 44/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4012 - loss: 0.2723 - val_accuracy: 0.4142 - val_loss: 0.3251
# Epoch 45/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4030 - loss: 0.2688 - val_accuracy: 0.4043 - val_loss: 0.3230
# Epoch 46/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4018 - loss: 0.2676 - val_accuracy: 0.3978 - val_loss: 0.3243
# Epoch 47/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4105 - loss: 0.2657 - val_accuracy: 0.4163 - val_loss: 0.3203
# Epoch 48/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4170 - loss: 0.2646 - val_accuracy: 0.4053 - val_loss: 0.3290
# Epoch 49/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4107 - loss: 0.2761 - val_accuracy: 0.4207 - val_loss: 0.3126
# Epoch 50/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4261 - loss: 0.2573 - val_accuracy: 0.4180 - val_loss: 0.3157
# Epoch 51/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4126 - loss: 0.2634 - val_accuracy: 0.4275 - val_loss: 0.3155
# Epoch 52/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4197 - loss: 0.2646 - val_accuracy: 0.4087 - val_loss: 0.3132
# Epoch 53/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4076 - loss: 0.2587 - val_accuracy: 0.4221 - val_loss: 0.3174
# Epoch 54/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4214 - loss: 0.2605 - val_accuracy: 0.4224 - val_loss: 0.3076
# Epoch 55/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4115 - loss: 0.2572 - val_accuracy: 0.4081 - val_loss: 0.3103
# Epoch 56/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4191 - loss: 0.2619 - val_accuracy: 0.4286 - val_loss: 0.3048
# Epoch 57/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4222 - loss: 0.2586 - val_accuracy: 0.4193 - val_loss: 0.3014
# Epoch 58/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4249 - loss: 0.2532 - val_accuracy: 0.4139 - val_loss: 0.3049
# Epoch 59/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4125 - loss: 0.2548 - val_accuracy: 0.4248 - val_loss: 0.3037
# Epoch 60/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4089 - loss: 0.2583 - val_accuracy: 0.4170 - val_loss: 0.3026
# Epoch 61/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4244 - loss: 0.2502 - val_accuracy: 0.4170 - val_loss: 0.2994
# Epoch 62/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4220 - loss: 0.2505 - val_accuracy: 0.4146 - val_loss: 0.2988
# Epoch 63/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4189 - loss: 0.2580 - val_accuracy: 0.4234 - val_loss: 0.2967
# Epoch 64/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4295 - loss: 0.2472 - val_accuracy: 0.4105 - val_loss: 0.2995
# Epoch 65/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4145 - loss: 0.2534 - val_accuracy: 0.4340 - val_loss: 0.2947
# Epoch 66/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4169 - loss: 0.2466 - val_accuracy: 0.4111 - val_loss: 0.2929
# Epoch 67/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4235 - loss: 0.2452 - val_accuracy: 0.4255 - val_loss: 0.2955
# Epoch 68/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4173 - loss: 0.2489 - val_accuracy: 0.4084 - val_loss: 0.2919
# Epoch 69/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4153 - loss: 0.2502 - val_accuracy: 0.4019 - val_loss: 0.2948
# Epoch 70/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4129 - loss: 0.2452 - val_accuracy: 0.4293 - val_loss: 0.2890
# Epoch 71/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4138 - loss: 0.2469 - val_accuracy: 0.4330 - val_loss: 0.2917
# Epoch 72/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4192 - loss: 0.2476 - val_accuracy: 0.4224 - val_loss: 0.2890
# Epoch 73/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4250 - loss: 0.2455 - val_accuracy: 0.4146 - val_loss: 0.2920
# Epoch 74/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4184 - loss: 0.2442 - val_accuracy: 0.4255 - val_loss: 0.2891
# Epoch 75/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4282 - loss: 0.2458 - val_accuracy: 0.4149 - val_loss: 0.2883
# Epoch 76/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4203 - loss: 0.2443 - val_accuracy: 0.4248 - val_loss: 0.2889
# Epoch 77/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4246 - loss: 0.2441 - val_accuracy: 0.4170 - val_loss: 0.2863
# Epoch 78/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4165 - loss: 0.2407 - val_accuracy: 0.4111 - val_loss: 0.2915
# Epoch 79/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4281 - loss: 0.2422 - val_accuracy: 0.4077 - val_loss: 0.2879
# Epoch 80/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4211 - loss: 0.2442 - val_accuracy: 0.4258 - val_loss: 0.2863
# Epoch 81/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4236 - loss: 0.2419 - val_accuracy: 0.4204 - val_loss: 0.2868
# Epoch 82/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4151 - loss: 0.2484 - val_accuracy: 0.4323 - val_loss: 0.2907
# Epoch 83/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4242 - loss: 0.2403 - val_accuracy: 0.4040 - val_loss: 0.2971
# Epoch 84/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4139 - loss: 0.2465 - val_accuracy: 0.4122 - val_loss: 0.2874
# Epoch 85/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4228 - loss: 0.2453 - val_accuracy: 0.4149 - val_loss: 0.2854
# Epoch 86/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4212 - loss: 0.2383 - val_accuracy: 0.4224 - val_loss: 0.2828
# Epoch 87/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4204 - loss: 0.2322 - val_accuracy: 0.4046 - val_loss: 0.2900
# Epoch 88/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4283 - loss: 0.2357 - val_accuracy: 0.4443 - val_loss: 0.2881
# Epoch 89/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4248 - loss: 0.2347 - val_accuracy: 0.4269 - val_loss: 0.2885
# Epoch 90/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4185 - loss: 0.2402 - val_accuracy: 0.4255 - val_loss: 0.2846
# Epoch 91/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4300 - loss: 0.2344 - val_accuracy: 0.4354 - val_loss: 0.2857
# Epoch 92/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4280 - loss: 0.2426 - val_accuracy: 0.4193 - val_loss: 0.2869
# Epoch 93/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4282 - loss: 0.2332 - val_accuracy: 0.4463 - val_loss: 0.2840
# Epoch 94/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4275 - loss: 0.2341 - val_accuracy: 0.4272 - val_loss: 0.2902
# Epoch 95/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4279 - loss: 0.2369 - val_accuracy: 0.4398 - val_loss: 0.2903
# Epoch 96/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4260 - loss: 0.2371 - val_accuracy: 0.4289 - val_loss: 0.2902
# Epoch 97/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4347 - loss: 0.2353 - val_accuracy: 0.4334 - val_loss: 0.2852
# Epoch 98/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4304 - loss: 0.2382 - val_accuracy: 0.4265 - val_loss: 0.2785
# Epoch 99/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4380 - loss: 0.2384 - val_accuracy: 0.4306 - val_loss: 0.2798
# Epoch 100/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4346 - loss: 0.2338 - val_accuracy: 0.4241 - val_loss: 0.2810
# Epoch 101/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4387 - loss: 0.2307 - val_accuracy: 0.4272 - val_loss: 0.2750
# Epoch 102/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4324 - loss: 0.2281 - val_accuracy: 0.4320 - val_loss: 0.2775
# Epoch 103/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4310 - loss: 0.2363 - val_accuracy: 0.4293 - val_loss: 0.2760
# Epoch 104/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4413 - loss: 0.2292 - val_accuracy: 0.4347 - val_loss: 0.2737
# Epoch 105/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4410 - loss: 0.2307 - val_accuracy: 0.4320 - val_loss: 0.2729
# Epoch 106/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4325 - loss: 0.2283 - val_accuracy: 0.4327 - val_loss: 0.2747
# Epoch 107/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4379 - loss: 0.2308 - val_accuracy: 0.4354 - val_loss: 0.2747
# Epoch 108/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4389 - loss: 0.2299 - val_accuracy: 0.4470 - val_loss: 0.2718
# Epoch 109/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4477 - loss: 0.2286 - val_accuracy: 0.4412 - val_loss: 0.2755
# Epoch 110/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4299 - loss: 0.2272 - val_accuracy: 0.4511 - val_loss: 0.2730
# Epoch 111/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4422 - loss: 0.2277 - val_accuracy: 0.4453 - val_loss: 0.2774
# Epoch 112/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4316 - loss: 0.2288 - val_accuracy: 0.4405 - val_loss: 0.2744
# Epoch 113/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4355 - loss: 0.2303 - val_accuracy: 0.4470 - val_loss: 0.2744
# Epoch 114/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4443 - loss: 0.2338 - val_accuracy: 0.4604 - val_loss: 0.2735
# Epoch 115/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4440 - loss: 0.2328 - val_accuracy: 0.4419 - val_loss: 0.2685
# Epoch 116/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4349 - loss: 0.2302 - val_accuracy: 0.4323 - val_loss: 0.2728
# Epoch 117/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4496 - loss: 0.2292 - val_accuracy: 0.4556 - val_loss: 0.2709
# Epoch 118/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4440 - loss: 0.2273 - val_accuracy: 0.4498 - val_loss: 0.2732
# Epoch 119/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4507 - loss: 0.2297 - val_accuracy: 0.4522 - val_loss: 0.2686
# Epoch 120/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4480 - loss: 0.2257 - val_accuracy: 0.4306 - val_loss: 0.2759
# Epoch 121/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4373 - loss: 0.2313 - val_accuracy: 0.4522 - val_loss: 0.2681
# Epoch 122/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4459 - loss: 0.2256 - val_accuracy: 0.4378 - val_loss: 0.2746
# Epoch 123/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4480 - loss: 0.2267 - val_accuracy: 0.4566 - val_loss: 0.2742
# Epoch 124/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4473 - loss: 0.2303 - val_accuracy: 0.4457 - val_loss: 0.2660
# Epoch 125/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4443 - loss: 0.2239 - val_accuracy: 0.4539 - val_loss: 0.2663
# Epoch 126/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4573 - loss: 0.2232 - val_accuracy: 0.4494 - val_loss: 0.2652
# Epoch 127/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4514 - loss: 0.2253 - val_accuracy: 0.4344 - val_loss: 0.2669
# Epoch 128/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4581 - loss: 0.2214 - val_accuracy: 0.4627 - val_loss: 0.2643
# Epoch 129/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4450 - loss: 0.2237 - val_accuracy: 0.4361 - val_loss: 0.2667
# Epoch 130/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4466 - loss: 0.2247 - val_accuracy: 0.4385 - val_loss: 0.2711
# Epoch 131/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4426 - loss: 0.2254 - val_accuracy: 0.4457 - val_loss: 0.2627
# Epoch 132/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4490 - loss: 0.2232 - val_accuracy: 0.4310 - val_loss: 0.2708
# Epoch 133/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4446 - loss: 0.2260 - val_accuracy: 0.4583 - val_loss: 0.2667
# Epoch 134/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4566 - loss: 0.2209 - val_accuracy: 0.4412 - val_loss: 0.2600
# Epoch 135/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4485 - loss: 0.2219 - val_accuracy: 0.4539 - val_loss: 0.2618
# Epoch 136/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4506 - loss: 0.2192 - val_accuracy: 0.4549 - val_loss: 0.2631
# Epoch 137/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4492 - loss: 0.2264 - val_accuracy: 0.4429 - val_loss: 0.2605
# Epoch 138/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4506 - loss: 0.2235 - val_accuracy: 0.4532 - val_loss: 0.2597
# Epoch 139/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4612 - loss: 0.2209 - val_accuracy: 0.4552 - val_loss: 0.2634
# Epoch 140/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4560 - loss: 0.2234 - val_accuracy: 0.4532 - val_loss: 0.2604
# Epoch 141/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4429 - loss: 0.2220 - val_accuracy: 0.4504 - val_loss: 0.2576
# Epoch 142/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4524 - loss: 0.2190 - val_accuracy: 0.4542 - val_loss: 0.2622
# Epoch 143/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4532 - loss: 0.2252 - val_accuracy: 0.4378 - val_loss: 0.2580
# Epoch 144/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4532 - loss: 0.2180 - val_accuracy: 0.4545 - val_loss: 0.2611
# Epoch 145/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4519 - loss: 0.2232 - val_accuracy: 0.4593 - val_loss: 0.2586
# Epoch 146/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4463 - loss: 0.2246 - val_accuracy: 0.4467 - val_loss: 0.2764
# Epoch 147/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4614 - loss: 0.2203 - val_accuracy: 0.4569 - val_loss: 0.2573
# Epoch 148/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4498 - loss: 0.2214 - val_accuracy: 0.4651 - val_loss: 0.2563
# Epoch 149/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4529 - loss: 0.2192 - val_accuracy: 0.4590 - val_loss: 0.2563
# Epoch 150/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4569 - loss: 0.2197 - val_accuracy: 0.4573 - val_loss: 0.2559
# Epoch 151/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4547 - loss: 0.2196 - val_accuracy: 0.4518 - val_loss: 0.2551
# Epoch 152/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4670 - loss: 0.2179 - val_accuracy: 0.4733 - val_loss: 0.2561
# Epoch 153/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4555 - loss: 0.2197 - val_accuracy: 0.4563 - val_loss: 0.2599
# Epoch 154/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4514 - loss: 0.2175 - val_accuracy: 0.4703 - val_loss: 0.2558
# Epoch 155/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4656 - loss: 0.2200 - val_accuracy: 0.4552 - val_loss: 0.2552
# Epoch 156/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4508 - loss: 0.2200 - val_accuracy: 0.4621 - val_loss: 0.2549
# Epoch 157/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4579 - loss: 0.2134 - val_accuracy: 0.4655 - val_loss: 0.2540
# Epoch 158/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4577 - loss: 0.2173 - val_accuracy: 0.4692 - val_loss: 0.2634
# Epoch 159/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4663 - loss: 0.2293 - val_accuracy: 0.4573 - val_loss: 0.2573
# Epoch 160/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4592 - loss: 0.2162 - val_accuracy: 0.4703 - val_loss: 0.2524
# Epoch 161/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4568 - loss: 0.2177 - val_accuracy: 0.4679 - val_loss: 0.2527
# Epoch 162/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4599 - loss: 0.2151 - val_accuracy: 0.4576 - val_loss: 0.2520
# Epoch 163/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4568 - loss: 0.2175 - val_accuracy: 0.4651 - val_loss: 0.2580
# Epoch 164/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4633 - loss: 0.2145 - val_accuracy: 0.4853 - val_loss: 0.2524
# Epoch 165/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4688 - loss: 0.2163 - val_accuracy: 0.4682 - val_loss: 0.2533
# Epoch 166/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4601 - loss: 0.2223 - val_accuracy: 0.4651 - val_loss: 0.2535
# Epoch 167/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4620 - loss: 0.2115 - val_accuracy: 0.4716 - val_loss: 0.2563
# Epoch 168/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4568 - loss: 0.2189 - val_accuracy: 0.4634 - val_loss: 0.2519
# Epoch 169/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4630 - loss: 0.2165 - val_accuracy: 0.4651 - val_loss: 0.2501
# Epoch 170/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4657 - loss: 0.2164 - val_accuracy: 0.4576 - val_loss: 0.2527
# Epoch 171/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4528 - loss: 0.2163 - val_accuracy: 0.4737 - val_loss: 0.2522
# Epoch 172/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4652 - loss: 0.2138 - val_accuracy: 0.4532 - val_loss: 0.2555
# Epoch 173/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4598 - loss: 0.2156 - val_accuracy: 0.4692 - val_loss: 0.2488
# Epoch 174/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4646 - loss: 0.2155 - val_accuracy: 0.4744 - val_loss: 0.2528
# Epoch 175/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4545 - loss: 0.2129 - val_accuracy: 0.4744 - val_loss: 0.2541
# Epoch 176/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4568 - loss: 0.2138 - val_accuracy: 0.4604 - val_loss: 0.2494
# Epoch 177/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4648 - loss: 0.2135 - val_accuracy: 0.4733 - val_loss: 0.2492
# Epoch 178/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4661 - loss: 0.2134 - val_accuracy: 0.4679 - val_loss: 0.2496
# Epoch 179/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4664 - loss: 0.2140 - val_accuracy: 0.4761 - val_loss: 0.2488
# Epoch 180/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4651 - loss: 0.2167 - val_accuracy: 0.4781 - val_loss: 0.2496
# Epoch 181/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4698 - loss: 0.2152 - val_accuracy: 0.4624 - val_loss: 0.2500
# Epoch 182/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4659 - loss: 0.2158 - val_accuracy: 0.4576 - val_loss: 0.2536
# Epoch 183/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4679 - loss: 0.2130 - val_accuracy: 0.4655 - val_loss: 0.2514
# Epoch 184/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4670 - loss: 0.2119 - val_accuracy: 0.4699 - val_loss: 0.2475
# Epoch 185/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4717 - loss: 0.2079 - val_accuracy: 0.4600 - val_loss: 0.2491
# Epoch 186/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4699 - loss: 0.2115 - val_accuracy: 0.4679 - val_loss: 0.2513
# Epoch 187/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4699 - loss: 0.2150 - val_accuracy: 0.4563 - val_loss: 0.2513
# Epoch 188/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4676 - loss: 0.2159 - val_accuracy: 0.4665 - val_loss: 0.2506
# Epoch 189/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4682 - loss: 0.2096 - val_accuracy: 0.4809 - val_loss: 0.2497
# Epoch 190/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4689 - loss: 0.2103 - val_accuracy: 0.4747 - val_loss: 0.2473
# Epoch 191/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4642 - loss: 0.2086 - val_accuracy: 0.4631 - val_loss: 0.2479
# Epoch 192/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4628 - loss: 0.2122 - val_accuracy: 0.4559 - val_loss: 0.2483
# Epoch 193/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4537 - loss: 0.2142 - val_accuracy: 0.4641 - val_loss: 0.2493
# Epoch 194/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4628 - loss: 0.2115 - val_accuracy: 0.4781 - val_loss: 0.2525
# Epoch 195/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4727 - loss: 0.2119 - val_accuracy: 0.4744 - val_loss: 0.2462
# Epoch 196/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4775 - loss: 0.2093 - val_accuracy: 0.4716 - val_loss: 0.2486
# Epoch 197/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4657 - loss: 0.2145 - val_accuracy: 0.4778 - val_loss: 0.2478
# Epoch 198/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4741 - loss: 0.2111 - val_accuracy: 0.4843 - val_loss: 0.2481
# Epoch 199/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4615 - loss: 0.2109 - val_accuracy: 0.4768 - val_loss: 0.2511
# Epoch 200/200
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4669 - loss: 0.2101 - val_accuracy: 0.4638 - val_loss: 0.2541

# %% [markdown]
# Classification

# %%
valid_x_predictions = autoencoder.predict(df_valid_x_rescaled)
mse = np.mean(np.power(df_valid_x_rescaled - valid_x_predictions, 2), axis=1)
error_df = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': df_valid['y']})
precision_rt, recall_rt, threshold_rt = precision_recall_curve(error_df.True_class, error_df.Reconstruction_error)
plt.plot(threshold_rt, precision_rt[1:], label="Precision",linewidth=5)
plt.plot(threshold_rt, recall_rt[1:], label="Recall",linewidth=5)
plt.title('Precision and recall for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision/Recall')
plt.legend()
plt.show()
# Out:
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step

# %%
test_x_predictions = autoencoder.predict(df_test_x_rescaled)
mse = np.mean(np.power(df_test_x_rescaled - test_x_predictions, 2), axis=1)
error_df_test = pd.DataFrame({'Reconstruction_error': mse,
                        'True_class': df_test['y']})
error_df_test = error_df_test.reset_index()
# Out:
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step

# %%
threshold_fixed = 0.2

groups = error_df_test.groupby('True_class')
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.index, group.Reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Break" if name == 1 else "Normal")
ax.hlines(threshold_fixed, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
pred_y = [1 if e > threshold_fixed else 0 for e in error_df.Reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.True_class, pred_y)
plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
false_pos_rate, true_pos_rate, thresholds = roc_curve(error_df.True_class, error_df.Reconstruction_error)
roc_auc = auc(false_pos_rate, true_pos_rate,)
plt.plot(false_pos_rate, true_pos_rate, linewidth=5, label='AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth=5)
plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
